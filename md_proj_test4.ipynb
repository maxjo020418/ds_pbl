# %%
import geopandas

# %%
gdf = geopandas.read_file('data/gadm41_KOR_shp/gadm41_KOR_2.shp')

gdf
# Out:
#           GID_2 GID_0      COUNTRY     GID_1 NAME_1      NL_NAME_1    NAME_2  \
# 0     KOR.1.1_2   KOR  South Korea   KOR.1_1  Busan  부산광역시 | 釜山廣域市       Buk
# 1     KOR.1.2_2   KOR  South Korea   KOR.1_1  Busan  부산광역시 | 釜山廣域市  Busanjin
# 2     KOR.1.3_2   KOR  South Korea   KOR.1_1  Busan  부산광역시 | 釜山廣域市      Dong
# 3     KOR.1.4_2   KOR  South Korea   KOR.1_1  Busan  부산광역시 | 釜山廣域市   Dongnae
# 4     KOR.1.5_2   KOR  South Korea   KOR.1_1  Busan  부산광역시 | 釜山廣域市   Gangseo
# ..          ...   ...          ...       ...    ...            ...       ...
# 224  KOR.17.1_2   KOR  South Korea  KOR.17_1  Ulsan  울산광역시 | 蔚山廣域市       Buk
# 225  KOR.17.2_2   KOR  South Korea  KOR.17_1  Ulsan  울산광역시 | 蔚山廣域市      Dong
# 226  KOR.17.3_2   KOR  South Korea  KOR.17_1  Ulsan  울산광역시 | 蔚山廣域市      Jung
# 227  KOR.17.4_2   KOR  South Korea  KOR.17_1  Ulsan  울산광역시 | 蔚山廣域市       Nam
# 228  KOR.17.5_2   KOR  South Korea  KOR.17_1  Ulsan  울산광역시 | 蔚山廣域市      Ulju
#
# ...

# %%
gdf.plot('NL_NAME_1')
# Out:
# <Axes: >

# %%
seoul = gdf.loc[gdf['NAME_1'] == 'Seoul']
seoul.plot("NAME_2")
# Out:
# <Axes: >
