# %% [markdown]
# ```graphql
# [out:json][timeout:180];
#
# // 서울지역 설정
# // area["ISO3166-2"="KR-11"][admin_level=4][boundary="administrative"]->.searchArea;
#
# // 전국 설정
# area["ISO3166-1"="KR"][admin_level=2]->.searchArea;
#
# // 서울 안에 있는 도서관 선택
# (
#   node["amenity"="library"](area.searchArea);
#   // way["amenity"="library"](area.searchArea);
#   // relation["amenity"="library"](area.searchArea);
# );
#
# // JSON으로 자료 (좌표, 이름 등) 포함해서 출력
# out center;
# ```

# %%
import requests
import pandas as pd

# %%
url = "https://overpass-api.de/api/interpreter"
query = """
[out:json][timeout:180];
area["ISO3166-1"="KR"][admin_level=2]->.searchArea;
(
  node["amenity"="library"](area.searchArea);
);
out center;
"""

r = requests.post(url, data={"data": query})
data: dict = r.json()

# %%
[print(k, type(v)) for k, v in data.items()]
print()
print(data['elements'][0])
# Out:
# version <class 'float'>
# generator <class 'str'>
# osm3s <class 'dict'>
# elements <class 'list'>
#
# {'type': 'node', 'id': 368652466, 'lat': 37.497318, 'lon': 127.003258, 'tags': {'amenity': 'library', 'check_date': '2024-01-26', 'name': '국립중앙도서관', 'name:en': 'National Jungang Library', 'name:ko': '국립중앙도서관', 'name:ko-Latn': 'Gungnipjungangdoseogwan', 'ncat': '도서관', 'source': 'http://kr.open.gugi.yahoo.com'}}

# %%
pd.DataFrame(data['elements'])
# Out:
#       type           id        lat         lon  \
# 0     node    368652466  37.497318  127.003258
# 1     node    368652476  37.554120  127.024842
# 2     node    368652481  37.566794  127.051319
# 3     node    368652535  37.565982  126.806533
# 4     node    368652537  37.495475  127.033180
# ...    ...          ...        ...         ...
# 1491  node  12797156099  36.594207  129.090320
# 1492  node  12811661729  37.593318  126.904741
# 1493  node  12811661730  37.593300  126.905438
# 1494  node  12821508806  37.490632  127.004958
# 1495  node  12833450050  37.345877  127.953663
#
#                                                    tags
# 0     {'amenity': 'library', 'check_date': '2024-01-...
# 1     {'amenity': 'library', 'name': '성동구립금호도서관', 'n...
# 2     {'amenity': 'library', 'name': '성동구립용답도서관', 'n...
# 3     {'amenity': 'library', 'name': '원이영어도서관', 'nam...
# 4     {'amenity': 'library', 'name': '역삼도서관', 'name:...
# ...                                                 ...
# 1491         {'amenity': 'library', 'name': '입암면작은도서관'}
# 1492  {'access': 'permit', 'amenity': 'library', 'na...
# 1493  {'access': 'permit', 'amenity': 'library', 'na...
# 1494  {'addr:city': '서울특별시', 'addr:district': '서초구',...
# 1495            {'amenity': 'library', 'name': '말씀의 방'}
#
# [1496 rows x 5 columns]

# %%
pd.DataFrame(pd.json_normalize(data['elements']))
# Out:
#       type           id        lat         lon tags.amenity tags.check_date  \
# 0     node    368652466  37.497318  127.003258      library      2024-01-26
# 1     node    368652476  37.554120  127.024842      library             NaN
# 2     node    368652481  37.566794  127.051319      library             NaN
# 3     node    368652535  37.565982  126.806533      library             NaN
# 4     node    368652537  37.495475  127.033180      library             NaN
# ...    ...          ...        ...         ...          ...             ...
# 1491  node  12797156099  36.594207  129.090320      library             NaN
# 1492  node  12811661729  37.593318  126.904741      library             NaN
# 1493  node  12811661730  37.593300  126.905438      library             NaN
# 1494  node  12821508806  37.490632  127.004958      library      2025-05-09
# 1495  node  12833450050  37.345877  127.953663      library             NaN
#
#        tags.name                     tags.name:en tags.name:ko  \
# 0        국립중앙도서관         National Jungang Library      국립중앙도서관
# 1      성동구립금호도서관     Seongdongguripgeumho Library    성동구립금호도서관
# 2      성동구립용답도서관    Seongdongguripyongdap Library    성동구립용답도서관
# 3        원이영어도서관              Woniyeongeo Library      원이영어도서관
# 4          역삼도서관                  Yeoksam Library        역삼도서관
# ...          ...                              ...          ...
# 1491    입암면작은도서관                              NaN          NaN
# 1492   숭실고등학교도서관                              NaN          NaN
# 1493    숭실중학교도서관                              NaN          NaN
# 1494  서초 그림책 도서관  Seocho Illustrated Book Library   서초 그림책 도서관
# 1495       말씀의 방                              NaN          NaN
#
#                    tags.name:ko-Latn  ... tags.opening_date tags.description  \
# 0            Gungnipjungangdoseogwan  ...               NaN              NaN
# 1      Seongdongguripgeumhodoseogwan  ...               NaN              NaN
# 2     Seongdongguripyongdapdoseogwan  ...               NaN              NaN
# 3               Woniyeongeodoseogwan  ...               NaN              NaN
# 4                   Yeoksamdoseogwan  ...               NaN              NaN
# ...                              ...  ...               ...              ...
# 1491                             NaN  ...               NaN              NaN
# 1492                             NaN  ...               NaN              NaN
# 1493                             NaN  ...               NaN              NaN
# 1494       Seocho Grimchak Doseogwan  ...               NaN              NaN
# 1495                             NaN  ...               NaN              NaN
#
#      tags.operator:wikidata tags.ref tags.name:es tags.access tags.addr:unit  \
# 0                       NaN      NaN          NaN         NaN            NaN
# 1                       NaN      NaN          NaN         NaN            NaN
# 2                       NaN      NaN          NaN         NaN            NaN
# 3                       NaN      NaN          NaN         NaN            NaN
# 4                       NaN      NaN          NaN         NaN            NaN
# ...                     ...      ...          ...         ...            ...
# 1491                    NaN      NaN          NaN         NaN            NaN
# 1492                    NaN      NaN          NaN      permit            NaN
# 1493                    NaN      NaN          NaN      permit            NaN
# 1494                    NaN      NaN          NaN         NaN            NaN
# 1495                    NaN      NaN          NaN         NaN            NaN
#
#      tags.baby_feeding                                         tags.image  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ...                ...                                                ...
# 1491               NaN                                                NaN
# 1492               NaN                                                NaN
# 1493               NaN                                                NaN
# 1494               yes  https://picturebook.seocholib.or.kr/img/%EB%8F...
# 1495               NaN                                                NaN
#
#      tags.not:name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1491           NaN
# 1492           NaN
# 1493           NaN
# 1494           NaN
# 1495           NaN
#
# [1496 rows x 63 columns]

# %% [markdown]
# `json_normalize`써서 묶여있는 `tags` 펼치기

# %%
df = pd.DataFrame(pd.json_normalize(data['elements']))[['lat', 'lon', 'tags.name']]
df.columns = ['lat', 'lon', 'name']
df
# Out:
#             lat         lon        name
# 0     37.497318  127.003258     국립중앙도서관
# 1     37.554120  127.024842   성동구립금호도서관
# 2     37.566794  127.051319   성동구립용답도서관
# 3     37.565982  126.806533     원이영어도서관
# 4     37.495475  127.033180       역삼도서관
# ...         ...         ...         ...
# 1491  36.594207  129.090320    입암면작은도서관
# 1492  37.593318  126.904741   숭실고등학교도서관
# 1493  37.593300  126.905438    숭실중학교도서관
# 1494  37.490632  127.004958  서초 그림책 도서관
# 1495  37.345877  127.953663       말씀의 방
#
# [1496 rows x 3 columns]

# %% [markdown]
# Nan있는지 확인하기

# %%
print(any(df.lat.isna()))
print(any(df.lon.isna()))
print(any(df.name.isna()))
# Out:
# False
# False
# True

# %% [markdown]
# 빈 값들 있는 행들은 제거

# %%
df.dropna(inplace=True)
len(df)
# Out:
# 1466

# %% [markdown]
# 이름 안에 '도서관'이 안 들어간 경우가 있음 - 서점, 유사 시설 또는 오표기인 것으로 확인
#
# (`~`는 series의 bool mask를 리버스한거)

# %%
df[~df.name.str.contains('도서관', case=False, regex=False)]
# Out:
#             lat         lon               name
# 14    37.450003  126.906022        금천은행나무어린이문고
# 19    37.557305  127.151679             고덕1동문고
# 20    37.628858  127.069827             공릉3동문고
# 21    37.664508  127.063828             상계9동문고
# 22    37.514502  126.859455             신정7동문고
# ...         ...         ...                ...
# 1474  34.740504  127.732387        2019물벼락만화카페
# 1477  37.623550  127.068815            한내지혜의 숲
# 1483  36.005855  129.335460           캔두 스터디카페
# 1489  37.330421  127.090194  Dongcheon Library
# 1495  37.345877  127.953663              말씀의 방
#
# [659 rows x 3 columns]

# %% [markdown]
# 이중에서 '문고'가 들어간 이름이 많은데 이는 주민센터 도서관인데 이름이 잘못 기입된것이 대부분
#
# (한글 -> 영어 -> 한글, OSM에서 자동 수집할 때 일어난 문제인 듯 함)
#
# 소규모 도서관이고 모든 도서관의 진위 확인 여부가 어려우므로 제외하기로 결정함.

# %%
df[
    df.name.str.contains('문고', case=False, regex=False) &
    ~df.name.str.contains('도서관', case=False, regex=False)
]
# Out:
#             lat         lon         name
# 14    37.450003  126.906022  금천은행나무어린이문고
# 19    37.557305  127.151679       고덕1동문고
# 20    37.628858  127.069827       공릉3동문고
# 21    37.664508  127.063828       상계9동문고
# 22    37.514502  126.859455       신정7동문고
# ...         ...         ...          ...
# 1006  34.609471  127.289045       고흥학림문고
# 1007  34.744359  127.263374       신기구심문고
# 1008  34.676561  127.266517       성두구심문고
# 1151  37.489409  126.948201        파랑새문고
# 1414  37.583000  127.088054    새마을문고면목3동
#
# [555 rows x 3 columns]

# %% [markdown]
# 최종 필터링은 '도서관'이 포함된 장소만 포함하기로 결정

# %%
df_final = df[
    df.name.str.contains('도서관', case=False, regex=False)
]
df_final
# Out:
#             lat         lon               name
# 0     37.497318  127.003258            국립중앙도서관
# 1     37.554120  127.024842          성동구립금호도서관
# 2     37.566794  127.051319          성동구립용답도서관
# 3     37.565982  126.806533            원이영어도서관
# 4     37.495475  127.033180              역삼도서관
# ...         ...         ...                ...
# 1490  35.168822  129.155652  부산광역시립해운대도서관 우동분관
# 1491  36.594207  129.090320           입암면작은도서관
# 1492  37.593318  126.904741          숭실고등학교도서관
# 1493  37.593300  126.905438           숭실중학교도서관
# 1494  37.490632  127.004958         서초 그림책 도서관
#
# [807 rows x 3 columns]

# %% [markdown]
# ---
#
# https://programmablesearchengine.google.com

# %%
import os
from dotenv import load_dotenv
load_dotenv()

CX = os.getenv("CX")
KEY = os.getenv("KEY")

# %%
params = {
    "cx": CX,
    "key": KEY,
    "exactTerms": '역삼도서관',
}

r = requests.get(
    "https://customsearch.googleapis.com/customsearch/v1",
    params=params
)

results = r.json()

# %%
len(results)
# Out:
# 6

# %%
len(results['items'])
# Out:
# 10

# %%
results['items']
# Out:
# [{'kind': 'customsearch#result',
#   'title': '[무료 공간] 역삼·강남역 "역삼 도서관" 후기 (위치, 운영 시간, 전화번호 ...',
#   'htmlTitle': '[무료 공간] 역삼·강남역 &quot;<b>역삼 도서관</b>&quot; 후기 (위치, 운영 시간, 전화번호 ...',
#   'link': 'https://blog.naver.com/cco0531/223368440851',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Feb 29, 2024 ... 서울 강남구 역삼 도서관에 방문하였습니다! (역삼역, 강남역 근처). \u200b. 건물 옆에 공영주차장도 있습니다!',
#   'htmlSnippet': 'Feb 29, 2024 <b>...</b> 서울 강남구 <b>역삼 도서관</b>에 방문하였습니다! (역삼역, 강남역 근처). \u200b. 건물 옆에 공영주차장도 있습니다!',
#   'formattedUrl': 'https://blog.naver.com/cco0531/223368440851',
#   'htmlFormattedUrl': 'https://blog.naver.com/cco0531/223368440851',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJ2h2Dt7FtY37ZFRKVRCTJ8WPxhonvJ5-fIa4cRik-Be4dk1k2yHjM7sW8&s',
#      'width': '194',
#      'height': '259'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyNDAyMjVfNTgg/MDAxNzA4ODQ1NDk5NTQ2.dLS0Sru0C38awrLbnIG6ZoIN7EaWR0c09Fspvb1dmKEg.J1Dqe_33-zsX3ZMT_bR3RJZ9Xn7LftO2pin5zDSvVwYg.JPEG/IMG_8268.JPG?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 자기계발•독서•리뷰',
#      'og:title': '[무료 공간] 역삼·강남역 "역삼 도서관" 후기 (위치, 운영 시간, 전화번호, 주차장, 내부 사진 등)',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyNDEyMjFfMTM5/MDAxNzM0Nzg2MDI3NTgw.vH303VPSW8QxAkh63FWohrFjCrX0j-DW66Fuce2WkKog.uvvmdZjNIMPdJSV1k6lpRS0oYF7c3Mr_Ed1YKhMLPMsg.JPEG/profileImage.jpg?type=s1',
#      'napp-site-analysis': 'gdid=90000003_000000000000003401CBEC13,service=blog,collection=blog',
#      'og:description': '주말에 서울 강남구 역삼 도서관에 방문하였습니다! (역삼역, 강남역 근처) 건물 옆에 공영주차장도 있습니...',
#      'referrer': 'always',
#      'naverblog:nickname': '유리해',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/cco0531/223368440851',
#      'og:article:author': '자기계발•.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAyNDAyMjVfNTgg/MDAxNzA4ODQ1NDk5NTQ2.dLS0Sru0C38awrLbnIG6ZoIN7EaWR0c09Fspvb1dmKEg.J1Dqe_33-zsX3ZMT_bR3RJZ9Xn7LftO2pin5zDSvVwYg.JPEG/IMG_8268.JPG?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '역삼도서관에 가다 : 네이버 블로그',
#   'htmlTitle': '<b>역삼도서관</b>에 가다 : 네이버 블로그',
#   'link': 'https://blog.naver.com/nsomdary/220603902769?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Jan 21, 2016 ... 제 마음대로 오두방정 탐험시리즈 4탄입니다. (아무것도 없다가 다짜고짜 네 번째라니!) ... 그 이름도 유명하지 않은 역삼 도서관입니다.',
#   'htmlSnippet': 'Jan 21, 2016 <b>...</b> 제 마음대로 오두방정 탐험시리즈 4탄입니다. (아무것도 없다가 다짜고짜 네 번째라니!) ... 그 이름도 유명하지 않은 <b>역삼 도서관</b>입니다.',
#   'formattedUrl': 'https://blog.naver.com/nsomdary/220603902769?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/nsomdary/220603902769?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSk_Q1aWTSEKK2gFILQunYcpvjmfomU0CwP8-mAfyc0tuP3Tkb8eofdRjvC&s',
#      'width': '299',
#      'height': '168'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/20160121_36/nsomdary_1453312171359LDOPW_JPEG/%C7%A5%C1%F6%C6%C7_%C6%C4%B6%FB.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 솜다리',
#      'og:title': '역삼도서관에 가다',
#      'naverblog:profile_image': 'https://ssl.pstatic.net/static/blog/m/img_default.gif',
#      'napp-site-analysis': 'gdid=90000003_00000000000000335D046B31,service=blog,collection=blog',
#      'og:description': '오늘은 테헤란로 주변을&nbsp;싸돌아다니는 제&nbsp;마음대로 오두방정 탐험시리즈 4탄입니다. (아무것도 ...',
#      'referrer': 'always',
#      'naverblog:nickname': '솜다리',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/nsomdary/220603902769',
#      'og:article:author': '솜다리 | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/20160121_36/nsomdary_1453312171359LDOPW_JPEG/%C7%A5%C1%F6%C6%C7_%C6%C4%B6%FB.jpg?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '역삼도서관 - 역삼 1동 주민센터(서울 강남구립 도서관, 회원증 ...',
#   'htmlTitle': '<b>역삼도서관</b> - 역삼 1동 주민센터(서울 강남구립 도서관, 회원증 ...',
#   'link': 'https://blog.naver.com/cityinorange/223412420184',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Apr 11, 2024 ... 역삼도서관은 평일 9시부터 22시까지 열고,. 주말에는 17시까지 열어요. \u200b. 역삼도서관 공부방인 집중학습실은. 매일 7\xa0...',
#   'htmlSnippet': 'Apr 11, 2024 <b>...</b> <b>역삼도서관</b>은 평일 9시부터 22시까지 열고,. 주말에는 17시까지 열어요. \u200b. <b>역삼도서관</b> 공부방인 집중학습실은. 매일 7&nbsp;...',
#   'formattedUrl': 'https://blog.naver.com/cityinorange/223412420184',
#   'htmlFormattedUrl': 'https://blog.naver.com/cityinorange/223412420184',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSkrUma5ihGwzjUaab9hV1dvNQJY4DVpTRxSNCQ-Hn644twvNUptlwz38Y&s',
#      'width': '259',
#      'height': '194'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyNDA0MTFfNzkg/MDAxNzEyODA2MDMyMjEy.gh3n7ZV9Gec1YqvEKqfepmxap1l1k9gJwWvWfn65hl8g.hOIRNJWKIh66b1G3ASHYU_0-NgFq_p8MkZurLggGH14g.JPEG/IMG_7692.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 라이또의 상상',
#      'og:title': '역삼도서관 - 역삼 1동 주민센터(서울 강남구립 도서관, 회원증, 멀티미디어실, 열람실, 집중학습실, 프린트, 복사기, 휴무일, 역삼역 도서관)',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyMjExMDRfMjI4/MDAxNjY3NTIxOTk2NzEw.wI1zqjtbay0jJcOyFh1egqYlFxbn4hHXApfeo0wBVcIg.ngIJ3FNU3WOYaLcc_foulj0XpaksuUBNtludnUU27qAg.PNG.cityinorange/profileImage.png?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000034046AFE58,service=blog,collection=blog',
#      'og:description': '역삼도서관 @ 역삼 1동 주민센터 안녕하세요! 라이또예요! 이번 포스팅에서는 역삼1동 주민센터에 있는 역...',
#      'referrer': 'always',
#      'naverblog:nickname': '라이또',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/cityinorange/223412420184',
#      'og:article:author': '라이또의 .. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://mblogthumb-phinf.pstatic.net/MjAyNDA0MTFfMjkx/MDAxNzEyODA2MDI4NzY1.n3kmDQbRZmcqgAHdDoBkhaknb8kJCGps3lb1cvkpCc0g.9FsGCqJ3T-2mM5mVnNeD-Ba43ei5agjpBXqo46T6SPEg.JPEG/IMG_7661.jpg?type=w400'}]}},
#  {'kind': 'customsearch#result',
#   'title': '임경선의 소작(作)소작 글짓기 후기 ① (@역삼도서관) : 네이버 블로그',
#   'htmlTitle': '임경선의 소작(作)소작 글짓기 후기 ① (@<b>역삼도서관</b>) : 네이버 블로그',
#   'link': 'https://blog.naver.com/vividashley/222079124615?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Sep 3, 2020 ... 오늘의 주제는 작가님 덕질은 아니고,. 역삼도서관에서 주관한 소작소작 글짓기 특강에 수강신청 성공하여 (선착순 40명!) 어제 저녁 7시부터 온라인\xa0...',
#   'htmlSnippet': 'Sep 3, 2020 <b>...</b> 오늘의 주제는 작가님 덕질은 아니고,. <b>역삼도서관</b>에서 주관한 소작소작 글짓기 특강에 수강신청 성공하여 (선착순 40명!) 어제 저녁 7시부터 온라인&nbsp;...',
#   'formattedUrl': 'https://blog.naver.com/vividashley/222079124615?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/vividashley/222079124615?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZ5i7cCtGZOuwfjwvUhTM2dmuOKfN6qGjHr8EZ83DuiA0Ha_iOaMT4_AI&s',
#      'width': '110',
#      'height': '162'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyMDA5MDNfMTYw/MDAxNTk5MTA1ODE2OTg3.4dsUEMxQrzr_T8NaBhqggm1nmA7VHATVyhiLErqI7Ugg.JVb7QxOVI3TN3RYycKsTjsSLhmzA9nl6-tAFzDJbGYEg.PNG.vividashley/%BD%BA%C5%A9%B8%B0%BC%A6_2020-09-02_%BF%C0%C8%C4_6.54.55.png?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 줄리아의 미식 여행',
#      'og:title': '임경선의 소작(作)소작 글짓기 후기 ① (@역삼도서관)',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyMDA4MTBfMTQ1/MDAxNTk3MDU2NjA4NDQ0.PBCKjGJ5RkwDZoN5TLEyin-K2evHLJKkVcF518-E76Ag.-LZ3yxfKkh1sYoE7XnNCK14XSPop0fYolNoReh-zbbUg.JPEG.vividashley/%25E1%2584%2587%25E1%2585%25AE%25E1%2584%2589%25E1%2585%25A1%25E1%2586%25AB%25E1%2584%2589%25E1%2585%25B5%25E1%2584%2590%25E1%2585%25B5.jpeg?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000033B4F28487,service=blog,collection=blog',
#      'og:description': '내가 유일하게 하는 덕질이 있다면 임경선 작가가 출간한 모든 책을 읽는 것이다. 20대~30대 초반엔 북토크...',
#      'referrer': 'always',
#      'naverblog:nickname': '남천동 줄리아',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/vividashley/222079124615',
#      'og:article:author': '줄리아의 .. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://bookthumb-phinf.pstatic.net/cover/141/160/14116013.jpg?type=m3&udate=20191026'}]}},
#  {'kind': 'customsearch#result',
#   'title': '나만 알고 싶은 역삼 도서관 이용후기(+스톰프뮤직) : 네이버 블로그',
#   'htmlTitle': '나만 알고 싶은 <b>역삼 도서관</b> 이용후기(+스톰프뮤직) : 네이버 블로그',
#   'link': 'https://blog.naver.com/PostView.naver?blogId=swimyans&logNo=222409327145&parentCategoryNo=&categoryNo=48&viewDate=&isShowPopularPosts=false&from=postView',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Jun 25, 2021 ... 안녕하세요. 얀스입니다 :) \u200b. 오늘은 저만 알고 싶은 "역삼 도서관" 포스팅을 하려고 합니다. 여기는 저의 회사(강남역) 근처 도서관으로 제가 애정\xa0...',
#   'htmlSnippet': 'Jun 25, 2021 <b>...</b> 안녕하세요. 얀스입니다 :) \u200b. 오늘은 저만 알고 싶은 &quot;<b>역삼 도서관</b>&quot; 포스팅을 하려고 합니다. 여기는 저의 회사(강남역) 근처 도서관으로 제가 애정&nbsp;...',
#   'formattedUrl': 'https://blog.naver.com/PostView.naver?blogId...logNo...',
#   'htmlFormattedUrl': 'https://blog.naver.com/PostView.naver?blogId...logNo...',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQzL6s7Fo5g0l9c6t2dDwZfJ1nM4uG3eXLyqjv7Qsl_sXdbo1k4ZIv9zpo&s',
#      'width': '299',
#      'height': '168'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyMTA2MjRfMTQw/MDAxNjI0NTQ2MzkzOTIw.eCjv_97vQPH3zx0BvAOiT5yFIWMyk1BoWQNDUuLRHeQg.eXA-tx5q6g4yti3k9clPGMkb7KR2_w8Rfw9WWYnEUlYg.JPEG.sweetblueiz/KakaoTalk_20210624_231010397.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 오늘의 얀스',
#      'og:title': '나만 알고 싶은 역삼 도서관 이용후기(+스톰프뮤직)',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyMTA3MjRfMjM5/MDAxNjI3MTI3NzUyMzQ4.SUGvNvjyAup1hWeyTJjJAKqls-aOQvf8Ddhk_QhG4Psg.5J6CdU5NxpJ_SeZUKjSeF5_E0amcJAQUomtKYhpRkgIg.GIF.sweetblueiz/profileImage.gif?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000033C8A10229,service=blog,collection=blog',
#      'og:description': '안녕하세요. 얀스입니다 :) 오늘은 저만 알고 싶은 &quot;역삼 도서관&quot; 포스팅을 하려고 합니다. 여기...',
#      'referrer': 'always',
#      'naverblog:nickname': '얀스',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/swimyans/222409327145',
#      'og:article:author': '오늘의 얀.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://mblogthumb-phinf.pstatic.net/MjAyMTA2MjRfMTQw/MDAxNjI0NTQ2MzkzOTIw.eCjv_97vQPH3zx0BvAOiT5yFIWMyk1BoWQNDUuLRHeQg.eXA-tx5q6g4yti3k9clPGMkb7KR2_w8Rfw9WWYnEUlYg.JPEG.sweetblueiz/KakaoTalk_20210624_231010397.jpg?type=w800'}]}},
#  {'kind': 'customsearch#result',
#   'title': '가족 씨네마 콘서트-영화와 국악의 콜라보 (#역삼도서관 #역삼1문화 ...',
#   'htmlTitle': '가족 씨네마 콘서트-영화와 국악의 콜라보 (#<b>역삼도서관</b> #역삼1문화 ...',
#   'link': 'https://blog.naver.com/alicegangnam/221499626658',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Mar 28, 2019 ... 신청문의: 역삼도서관 508-1139 (자리가 한정되어있으니, 사전신청 바람.) ○ 공연팀: 날리굿. \u200b.',
#   'htmlSnippet': 'Mar 28, 2019 <b>...</b> 신청문의: <b>역삼도서관</b> 508-1139 (자리가 한정되어있으니, 사전신청 바람.) ○ 공연팀: 날리굿. \u200b.',
#   'formattedUrl': 'https://blog.naver.com/alicegangnam/221499626658',
#   'htmlFormattedUrl': 'https://blog.naver.com/alicegangnam/221499626658',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTv7NU0eccthYM6bealdTeAj2E4h2sdK4LIXpIeAxLgSS3ufoU7REKTuB8&s',
#      'width': '225',
#      'height': '225'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAxOTAzMjhfNDcg/MDAxNTUzNzU1MTI0ODg0.CeU7kvaJLwL8hZJxtwhB2FciROjKnJCVo_nCwqtFAH4g.ejckmlnfkf9QPGD-fEyVK_jdoSms1n3PTQ7NgKzbGp8g.PNG.alicegangnam/01.png?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 공식 블로그',
#      'og:title': '가족 씨네마 콘서트-영화와 국악의 콜라보 (#역삼도서관 #역삼1문화센터 #무료공연 #문화가있는날 #가족씨네마콘서트)',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyNDEyMjdfNjkg/MDAxNzM1Mjc2MjcyMzk3.NNE2oGP-aJ64-iVQJ2K0E5iA6afIlwTbJJAdA_xwiKQg.EZzl6vkAIerl_-OZLi3XpOl2V1mPaLHWuMkp22Wrtkkg.PNG/profileImage.png?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000033926814A2,service=blog,collection=blog',
#      'og:description': '가족 씨네마 콘서트-영화와 국악의 콜라보 날리굿과 함께하는 씨네마 콘서트, 흥이 나는 무대에 여러분을 ...',
#      'referrer': 'always',
#      'naverblog:nickname': '강남구청',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/alicegangnam/221499626658',
#      'og:article:author': '공식 블로.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAxOTAzMjhfNDcg/MDAxNTUzNzU1MTI0ODg0.CeU7kvaJLwL8hZJxtwhB2FciROjKnJCVo_nCwqtFAH4g.ejckmlnfkf9QPGD-fEyVK_jdoSms1n3PTQ7NgKzbGp8g.PNG.alicegangnam/01.png?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '역삼도서관 : 네이버 블로그',
#   'htmlTitle': '<b>역삼도서관</b> : 네이버 블로그',
#   'link': 'https://blog.naver.com/mist6721/222048991731?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Aug 2, 2020 ... ... 역삼도서관 · 공감한 사람 보러가기 · 댓글 2 공유하기. 프로필. 이웃추가. Stella. 어학·외국어이웃605명. Freelance Translator 그림그리는 번역쟁이 어\xa0...',
#   'htmlSnippet': 'Aug 2, 2020 <b>...</b> ... <b>역삼도서관</b> &middot; 공감한 사람 보러가기 &middot; 댓글 2 공유하기. 프로필. 이웃추가. Stella. 어학·외국어이웃605명. Freelance Translator 그림그리는 번역쟁이 어&nbsp;...',
#   'formattedUrl': 'https://blog.naver.com/mist6721/222048991731?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/mist6721/222048991731?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmkqHeK5bokeihg-NCERXBJhqahAGM3G9rH9LB4j2XHSukttO2JlsTMsY&s',
#      'width': '259',
#      'height': '194'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyMDA4MDJfMjAg/MDAxNTk2MzQ5NDk5NTE0.yyYQAVjFojVS0DXSO3G7L5Zt47H0MS9nBDYGL3TvuXIg.MkSQuXcKSqvyW1AJK4s9G8eAbPCf0f8jtZRmTaDu9YIg.JPEG.mist6721/20200802_144333.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 그림그리는 마녀',
#      'og:title': '역삼도서관',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAxNjExMjRfMTEy/MDAxNDc5OTg3MjQ3NTg2.RFAl_j_YfMrlpkfJKzTmLu-6qq9h_aLeFKi6i-9h4X0g.PtoIZjm9WyWsW3lq_dB7eaUMczzaBjpUklbtgvwf8a4g.JPEG.mist6721/profileImage.jpg?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000033B326B9F3,service=blog,collection=blog',
#      'og:description': '엄마 집에서 일주일 치 식량(?)을 조달하고 돌아왔다가, 우유를 사러 나갔다. 요즘 거의 신생아 뺨치게 우...',
#      'referrer': 'always',
#      'naverblog:nickname': 'Stella',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/mist6721/222048991731',
#      'og:article:author': '그림그리는.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAyMDA4MDJfMjAg/MDAxNTk2MzQ5NDk5NTE0.yyYQAVjFojVS0DXSO3G7L5Zt47H0MS9nBDYGL3TvuXIg.MkSQuXcKSqvyW1AJK4s9G8eAbPCf0f8jtZRmTaDu9YIg.JPEG.mist6721/20200802_144333.jpg?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '조용히 공부하기 좋은 강남 구립 역삼도서관 열람실 : 네이버 블로그',
#   'htmlTitle': '조용히 공부하기 좋은 강남 구립 <b>역삼도서관</b> 열람실 : 네이버 블로그',
#   'link': 'https://blog.naver.com/yaloo77/223055150611?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': "Mar 25, 2023 ... '강남구청 역삼도서관'이라는 작은 간판이 있습니다. \u200b. 들어가자마자 엘레베이터를 타고.",
#   'htmlSnippet': 'Mar 25, 2023 <b>...</b> &#39;강남구청 <b>역삼도서관</b>&#39;이라는 작은 간판이 있습니다. \u200b. 들어가자마자 엘레베이터를 타고.',
#   'formattedUrl': 'https://blog.naver.com/yaloo77/223055150611?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/yaloo77/223055150611?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfdoiHwcTafPwtwQvBxj0LaTIg5TW3ppG-WjX-MommAFz6z6cq2YclY5g&s',
#      'width': '259',
#      'height': '194'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAyMzAzMjVfMTcz/MDAxNjc5NzEwNjc1OTU5.97BV7um-QgurIbaacpxH3ZCUvu1_aIxdyEsKnXroPSUg.k7R8edgBtv8KjOSks78irleERVv0yXPnvRlbswely8kg.JPEG.yaloo77/1679710114971.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | ʚ나는야 째굥이ɞ',
#      'og:title': '조용히 공부하기 좋은 강남 구립 역삼도서관 열람실',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAyMjA4MDFfMTA5/MDAxNjU5MzQ2Mjg2MDU3.TYIvbk3vEMpvLiGmwgTWzVLvyhnGeWjnbU0wzx9iBMAg.7ngwcpKvvrsxsb-KNz1FSpXjDUYXVl_RQU6Qh3G9uxcg.PNG.yaloo77/profileImage.png?type=s1',
#      'napp-site-analysis': 'gdid=90000003_0000000000000033EF1F7E13,service=blog,collection=blog',
#      'og:description': '강남역과 역삼역 사이에 위치하고 있는 역삼도서관에 다녀왔습니다. 표지판에 역삼 도서관이 적혀 있어서 ...',
#      'referrer': 'always',
#      'naverblog:nickname': '째야',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/yaloo77/223055150611',
#      'og:article:author': 'ʚ나는야 .. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAyMzAzMjVfMTcz/MDAxNjc5NzEwNjc1OTU5.97BV7um-QgurIbaacpxH3ZCUvu1_aIxdyEsKnXroPSUg.k7R8edgBtv8KjOSks78irleERVv0yXPnvRlbswely8kg.JPEG.yaloo77/1679710114971.jpg?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '강남역 무료 공부 장소 추천 - 역삼도서관 : 네이버 블로그',
#   'htmlTitle': '강남역 무료 공부 장소 추천 - <b>역삼도서관</b> : 네이버 블로그',
#   'link': 'https://blog.naver.com/khykhyhy24/221225567053?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Mar 9, 2018 ... 그래서 찾은 곳이 역삼도서관!!! \u200b. \u200b. 당시 집에서 5분도 안걸리는 거리인데다가 90년대 아날로그적인 갬성이 남아있어(\xa0...',
#   'htmlSnippet': 'Mar 9, 2018 <b>...</b> 그래서 찾은 곳이 <b>역삼도서관</b>!!! \u200b. \u200b. 당시 집에서 5분도 안걸리는 거리인데다가 90년대 아날로그적인 갬성이 남아있어(&nbsp;...',
#   'formattedUrl': 'https://blog.naver.com/khykhyhy24/221225567053?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/khykhyhy24/221225567053?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRCbj2vpfIKISBXABYR0kU_HD9kJ8Ne9s4OiMeEzMaASCtyG5N9sF8vXiU&s',
#      'width': '259',
#      'height': '194'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAxODAzMDlfMTAg/MDAxNTIwNjAxMTIzODM2.HxbgEyG71CnLJRQPBU9FvBsOOiFNuptCAej44t-GDbYg.1rG2rTruBsP2ma6boC9qMXyM0C2kng7IXFbcuzDQcuEg.JPEG.khykhyhy24/IMG_0767.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 냠냠쩌비쩌비',
#      'og:title': '강남역 무료 공부 장소 추천 - 역삼도서관',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/20140320_5/khykhyhy24_1395319305698PmeEQ_JPEG/%C6%F9%B5%A55.jpg?type=s1',
#      'napp-site-analysis': 'gdid=90000003_00000000000000338212434D,service=blog,collection=blog',
#      'og:description': '작년에 미국 대학원 준비를 하면서 가장 많이 간 곳은 스벅인데 문제는 집중력이 필요할 땐 시끄럽다는 거...',
#      'referrer': 'always',
#      'naverblog:nickname': '챱챱챱',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/khykhyhy24/221225567053',
#      'og:article:author': '냠냠쩌비쩌.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAxODAzMDlfMTAg/MDAxNTIwNjAxMTIzODM2.HxbgEyG71CnLJRQPBU9FvBsOOiFNuptCAej44t-GDbYg.1rG2rTruBsP2ma6boC9qMXyM0C2kng7IXFbcuzDQcuEg.JPEG.khykhyhy24/IMG_0767.jpg?type=w2'}]}},
#  {'kind': 'customsearch#result',
#   'title': '[서울 강남구 역삼도서관] 나는 이기적으로 읽기로 했다 박노성 저자와 ...',
#   'htmlTitle': '[서울 강남구 <b>역삼도서관</b>] 나는 이기적으로 읽기로 했다 박노성 저자와 ...',
#   'link': 'https://blog.naver.com/nosung/221384969610?viewType=pc',
#   'displayLink': 'blog.naver.com',
#   'snippet': 'Oct 25, 2018 ... 서울 강남구 역삼도서관에서 저자와의 만남이 있습니다. 독서에 관심 있는 분들의 많은 관심과 참여 부탁드립니다. <강의 경력>',
#   'htmlSnippet': 'Oct 25, 2018 <b>...</b> 서울 강남구 <b>역삼도서관</b>에서 저자와의 만남이 있습니다. 독서에 관심 있는 분들의 많은 관심과 참여 부탁드립니다. &lt;강의 경력&gt;',
#   'formattedUrl': 'https://blog.naver.com/nosung/221384969610?viewType=pc',
#   'htmlFormattedUrl': 'https://blog.naver.com/nosung/221384969610?viewType=pc',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNf9uKpmN8Tyw6AhwsWFjruv2pptUL5ay-F8xNhSBHlH4WGfwVhc2OOxb7&s',
#      'width': '187',
#      'height': '270'}],
#    'metatags': [{'og:image': 'https://blogthumb.pstatic.net/MjAxODEwMjVfMjg1/MDAxNTQwNDYyMzgwOTcz.-oZGNhd_6lIiTVH5yoQPjIKJU7nvnNBA3dK9mGsKV0og.oiIIUwuwGI_Vgn_-mXu9Qzol44I4F-ZZW4Xx8JSpLhAg.JPEG.nosung/%BF%AA%BB%EF%B5%B5%BC%AD%B0%FC_%C6%F7%BD%BA%C5%CD.jpg?type=w2',
#      'og:type': 'article',
#      'og:site_name': '네이버 블로그 | 셰익스컴퍼니',
#      'og:title': '[서울 강남구 역삼도서관] 나는 이기적으로 읽기로 했다 박노성 저자와의 만남이 있습니다.',
#      'naverblog:profile_image': 'https://blogpfthumb-phinf.pstatic.net/MjAxODEyMTVfNzkg/MDAxNTQ0ODQ3MzEyNjI0.VEIR3bFF8eBZLlTj_XxoNda0B676fUShruNf24rP1Owg.YT40Y0zzJGgxMU7Aeq2MXSiqZpjUymtuJx44da5zJAsg.JPEG.nosung/KakaoTalk_20181215_115038244.jpg?type=s1',
#      'napp-site-analysis': 'gdid=90000003_00000000000000338B928D8A,service=blog,collection=blog',
#      'og:description': '서울 강남구 역삼도서관에서 저자와의 만남이 있습니다. 독서에 관심 있는 분들의 많은 관심과 참여 부탁드...',
#      'referrer': 'always',
#      'naverblog:nickname': '박노성',
#      'me:feed:serviceid': 'blog',
#      'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover',
#      'og:url': 'https://blog.naver.com/nosung/221384969610',
#      'og:article:author': '셰익스컴퍼.. | 블로그',
#      'format-detection': 'telephone=no'}],
#    'cse_image': [{'src': 'https://blogthumb.pstatic.net/MjAxODEwMjVfMjg1/MDAxNTQwNDYyMzgwOTcz.-oZGNhd_6lIiTVH5yoQPjIKJU7nvnNBA3dK9mGsKV0og.oiIIUwuwGI_Vgn_-mXu9Qzol44I4F-ZZW4Xx8JSpLhAg.JPEG.nosung/%BF%AA%BB%EF%B5%B5%BC%AD%B0%FC_%C6%F7%BD%BA%C5%CD.jpg?type=w2'}]}}]

# %%
import pickle as pkl

links = [l['link'] for l in results['items']]
[print(link) for link in links]

with open('./data_temp/links_.pkl', 'wb') as f:
    pkl.dump(links, f)
# Out:
# https://blog.naver.com/cco0531/223368440851
# https://blog.naver.com/nsomdary/220603902769?viewType=pc
# https://blog.naver.com/cityinorange/223412420184
# https://blog.naver.com/vividashley/222079124615?viewType=pc
# https://blog.naver.com/PostView.naver?blogId=swimyans&logNo=222409327145&parentCategoryNo=&categoryNo=48&viewDate=&isShowPopularPosts=false&from=postView
# https://blog.naver.com/alicegangnam/221499626658
# https://blog.naver.com/mist6721/222048991731?viewType=pc
# https://blog.naver.com/yaloo77/223055150611?viewType=pc
# https://blog.naver.com/khykhyhy24/221225567053?viewType=pc
# https://blog.naver.com/nosung/221384969610?viewType=pc

# %% [markdown]
# **note:**
#
# `get_se_fs`에서 구현한 "꼼수":
# 1. 프린트 링크 사용해서 필요없는 내용 정리
# 2. BeautifulSoup써서 parsing 진행
# 3. `span`안에 든 모든 텍스트 추출

# %%
import pickle as pkl
from parser import get_se_fs, to_postprint, get_span
from tqdm import tqdm

with open('./data_temp/links_.pkl', 'rb') as f:
    links = pkl.load(f)

postprint_links = [to_postprint(url) for url in links]
[print(p) for p in postprint_links]

with open('./data_temp/lib1.txt', mode='w+', encoding='utf-8') as f:
    for pl in tqdm(postprint_links):
        if pl:
            f.write(pl + '\n')
            f.write(get_span(pl) + '\n\n')
        else:
            print(f'skipping: {pl}')
# Out:
# https://blog.naver.com/PostPrint.naver?blogId=cco0531&logNo=223368440851
# https://blog.naver.com/PostPrint.naver?blogId=nsomdary&logNo=220603902769
# https://blog.naver.com/PostPrint.naver?blogId=cityinorange&logNo=223412420184
# https://blog.naver.com/PostPrint.naver?blogId=vividashley&logNo=222079124615
# None
# https://blog.naver.com/PostPrint.naver?blogId=alicegangnam&logNo=221499626658
# https://blog.naver.com/PostPrint.naver?blogId=mist6721&logNo=222048991731
# https://blog.naver.com/PostPrint.naver?blogId=yaloo77&logNo=223055150611
# https://blog.naver.com/PostPrint.naver?blogId=khykhyhy24&logNo=221225567053
# https://blog.naver.com/PostPrint.naver?blogId=nosung&logNo=221384969610
#  40%|████      | 4/10 [00:02<00:03,  1.61it/s]
# skipping: None
# 100%|██████████| 10/10 [00:03<00:00,  2.56it/s]
